# %% [markdown]
# # EXTRACTING WEATHER FEATURES

# %% [markdown]
# This is for extracting weather features from the two weather datasets provided. Creates an output dict from which desired features can be selected or all features can be combined with existing dataset

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# Read the training set

# %%
dftrain = pd.read_csv('train.csv', nrows = 10) #Reading first 10 rows to reduce execution time
dftrain.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %% [markdown]
# # USING CENTRAL PARK WEATHER DATASET

# %% [markdown]
# Read the weather features

# %%
dfweather = pd.read_csv('weather_2016.csv')
dfweather.head()
# Out:
#        date  maximum temerature  minimum temperature  average temperature  \
# 0  01-01-16                  44                   34                 39.0
# 1  02-01-16                  40                   30                 35.0
# 2  03-01-16                  46                   33                 39.5
# 3  04-01-16                  35                   13                 24.0
# 4  05-01-16                  29                   10                 19.5
#
#   precipitation snow fall snow depth
# 0             0         0          0
# 1             0         0          0
# 2             0         0          0
# 3             0         0          0
# 4             0         0          0

# %% [markdown]
# Index each row by the date

# %%
dfweather.set_index("date", inplace=True)
dfweather.head()
# Out:
#           maximum temerature  minimum temperature  average temperature  \
# date
# 01-01-16                  44                   34                 39.0
# 02-01-16                  40                   30                 35.0
# 03-01-16                  46                   33                 39.5
# 04-01-16                  35                   13                 24.0
# 05-01-16                  29                   10                 19.5
#
#          precipitation snow fall snow depth
# date
# 01-01-16             0         0          0
# 02-01-16             0         0          0
# 03-01-16             0         0          0
# 04-01-16             0         0          0
# 05-01-16             0         0          0

# %% [markdown]
# Function that extracts the features given an input date and returns a dict

# %%
def weather_extract(date):
    #Need to modify the date format from training and testing sets
    date_format = dt.datetime.strptime(date, '%Y-%m-%d').strftime('%d-%m-%y')
    
    #Output a dict containing features
    out = dict(dfweather.loc[date_format])
    return out

# %% [markdown]
# We can now extract desired features given a particular date

# %%
dftrain_weather = dftrain.copy(deep=True)
dftrain_weather.set_index("id", inplace=True)
dftrain_weather.apply(lambda row: pd.Series(weather_extract(row['pickup_datetime'][:10])), axis = 1)
# Out:
#            average temperature  maximum temerature  minimum temperature  \
# id
# id2875421                 45.0                  48                   42
# id2377394                 72.0                  84                   60
# id3858529                 24.5                  30                   19
# id3504673                 36.0                  46                   26
# id2181028                 42.5                  49                   36
# id0801584                 33.0                  40                   26
# id1813257                 69.5                  76                   63
# id1324603                 57.0                  63                   51
# id1301050                 70.0                  78                   62
# id0012891                 59.5                  68                   51
#
#           precipitation snow depth snow fall
# id
# id2875421          0.89          0         0
# id2377394             0          0         0
# id3858529             0          T         0
# id3504673             0          0         0
# id2181028             0          0         0
# id0801584             0          1         0
# id1813257             0          0         0
# id1324603             T          0         0
# id1301050             0          0         0
# id0012891             T          0         0

# %% [markdown]
# # USING THE KNYCMETARS DATASET

# %%
dfweather_knyc = pd.read_csv('knycmetars.csv') 
dfweather_knyc.head()
# Out:
#                   Time  Temp.  Windchill  Heat Index  Humidity  Pressure  \
# 0  2015-12-31 02:00:00    7.8        7.1         NaN      0.89    1017.0
# 1  2015-12-31 03:00:00    7.2        5.9         NaN      0.90    1016.5
# 2  2015-12-31 04:00:00    7.2        NaN         NaN      0.90    1016.7
# 3  2015-12-31 05:00:00    7.2        5.9         NaN      0.86    1015.9
# 4  2015-12-31 06:00:00    7.2        6.4         NaN      0.90    1016.2
#
#    Dew Point  Visibility  Wind Dir  Wind Speed  Gust Speed  Precip Events  \
# 0        6.1         8.0       NNE         5.6         0.0     0.8   None
# 1        5.6        12.9  Variable         7.4         0.0     0.3   None
# 2        5.6        12.9      Calm         0.0         0.0     0.0   None
# 3        5.0        14.5        NW         7.4         0.0     0.0   None
# 4        5.6        11.3      West         5.6         0.0     0.0   None
#
#   Conditions
# 0   Overcast
# 1   Overcast
# 2   Overcast
# 3   Overcast
# 4   Overcast

# %% [markdown]
# Index the dataset by timestamp

# %%
dfweather_knyc.set_index("Time", inplace=True)
dfweather_knyc.head()
# Out:
#                      Temp.  Windchill  Heat Index  Humidity  Pressure  \
# Time
# 2015-12-31 02:00:00    7.8        7.1         NaN      0.89    1017.0
# 2015-12-31 03:00:00    7.2        5.9         NaN      0.90    1016.5
# 2015-12-31 04:00:00    7.2        NaN         NaN      0.90    1016.7
# 2015-12-31 05:00:00    7.2        5.9         NaN      0.86    1015.9
# 2015-12-31 06:00:00    7.2        6.4         NaN      0.90    1016.2
#
#                      Dew Point  Visibility  Wind Dir  Wind Speed  Gust Speed  \
# Time
# 2015-12-31 02:00:00        6.1         8.0       NNE         5.6         0.0
# 2015-12-31 03:00:00        5.6        12.9  Variable         7.4         0.0
# 2015-12-31 04:00:00        5.6        12.9      Calm         0.0         0.0
# 2015-12-31 05:00:00        5.0        14.5        NW         7.4         0.0
# 2015-12-31 06:00:00        5.6        11.3      West         5.6         0.0
#
#                      Precip Events Conditions
# Time
# 2015-12-31 02:00:00     0.8   None   Overcast
# 2015-12-31 03:00:00     0.3   None   Overcast
# 2015-12-31 04:00:00     0.0   None   Overcast
# 2015-12-31 05:00:00     0.0   None   Overcast
# 2015-12-31 06:00:00     0.0   None   Overcast

# %% [markdown]
# Extract weather features from KNYC dataset

# %%
def weather_extract_knyc(pickup_datetime):
    timestamp = pickup_datetime.split()
    date = timestamp[0]
    time = timestamp[1]
    
    time_format = dt.datetime.strptime(time, '%H:%M:%S').strftime('%H:00:00')
    timestamp = date + ' ' + time_format
    
    #Output a dict containing features
    out = dict(dfweather_knyc.loc[timestamp])
    return out

# %% [markdown]
# The weather data can then be combined with existing dataset using the id

# %%
dftrain_knyc = dftrain.copy(deep=True)
dftrain_knyc.set_index("id",inplace=True)
dftrain_knyc.apply(lambda row: pd.Series(weather_extract_knyc(str(row['pickup_datetime']))), axis = 1)
# Out:
#           Conditions  Dew Point Events  Gust Speed  Heat Index  Humidity  \
# id
# id2875421   Overcast        2.2   None        57.4         NaN      0.86
# id2377394    Unknown       18.3   None         0.0        29.9      0.53
# id3858529      Clear      -16.7   None        46.3         NaN      0.46
# id3504673      Clear       -6.1   None        35.2         NaN      0.39
# id2181028      Clear       -1.7   None         0.0         NaN      0.46
# id0801584      Clear       -8.3   None        29.6         NaN      0.41
# id1813257      Clear        9.4   None         0.0         NaN      0.54
# id1324603      Clear        5.0   None         0.0         NaN      0.55
# id1301050      Clear       17.2   None         0.0         NaN      0.60
# id0012891   Overcast        8.9   None         0.0         NaN      0.38
#
#            Precip  Pressure  Temp.  Visibility  Wind Dir  Wind Speed  \
# id
# id2875421     0.3    1017.5    4.4         8.0       ENE        27.8
# id2377394     0.0    1006.6   28.9        16.1      West         7.4
# id3858529     0.0    1016.3   -6.7        16.1      West        24.1
# id3504673     0.0    1019.1    7.2        16.1     South        25.9
# id2181028     0.0    1026.9    9.4        16.1  Variable         9.3
# id0801584     0.0    1015.8    3.9        16.1        SW        16.7
# id1813257     0.0    1018.1   18.9        16.1  Variable         7.4
# id1324603     0.0    1021.3   13.9        16.1      Calm         0.0
# id1301050     0.0    1017.3   25.6        12.9  Variable         9.3
# id0012891     0.0    1011.8   23.9        16.1      West         7.4
#
#            Windchill
# id
# id2875421       -0.5
# id2377394        NaN
# id3858529      -14.3
# id3504673        3.3
# id2181028        NaN
# id0801584        0.2
# id1813257        NaN
# id1324603        NaN
# id1301050        NaN
# id0012891        NaN
